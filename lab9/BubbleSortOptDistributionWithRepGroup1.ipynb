# %% [markdown]
# ##**Bubble Sort Optimizado**##
#
# ####**Tiempo de complejidad:**####
# * **Mejor caso:** Arreglo ordenado $O(n)$, $(n-1)$ comparaciones y $0$ intercambios.
# * **Peor caso:** Arreglo en orden decreciente $O(n^2)$, $\frac{n(n-1)}{2}$ comparaciones y $\frac{n(n-1)}{2}$ intercambios
# * **Caso promedio:** Arreglo desordenado, ni creciente ni decreciente, número esperado de comparaciones + intercambios en permutación uniforme aleatoria de $ n $ elementos diferentes $O(n^2)$, o $T(n) = \frac{57}{80}n^2 - \frac{59}{80}n + \frac{2}{15}=\Theta(n^2)$ (fórmula hallada a partir de los 3 primeros casos estudiados)
#
# ####**Código:**####

# %%
def bubbleSort(array):
  steps = 0
  for i in range(len(array)):
    swapped = False
    for j in range(0, len(array) - i - 1):
      steps +=1
      if array[j] > array[j + 1]:
        steps +=1
        temp = array[j]
        array[j] = array[j+1]
        array[j+1] = temp
        swapped = True
    if not swapped:
      break
  return(steps)

# %% [markdown]
# ####**Histogramas para permutaciones de $ n $ elementos diferentes sin repeticiones:**####

# %%
from itertools import permutations
import matplotlib.pyplot as plt
import numpy as np 
import math

for j in range(3,11):

  n = j
  perm = permutations(range(1,n+1))

  times =  [] 
# Print the obtained permutations
  for i in list(perm):
    i = list(i)
    times.append(bubbleSort(i))

  b = np.array(range(min(times)-1,max(times)+2) ) +0.5
  plt.hist(times,bins=b)
  plt.title("Bubble Sort")
  plt.xlabel("Steps =comparisons + swaps ")
  plt.ylabel("Frequency")
  plt.show()
    
  print("n",n)  
  print("number of permutations n! =",math.factorial(n)) 
  print("exp min =",min(times))
  print("min formula (n-1) =",(n-1))
  print("exp max =",max(times))
  print("max formula (n-1)*n =",(n-1)*n)
  print("exp mean =",np.mean(times))
  print("mean formula 13/18(n**2-n) =",(57/80*n**2 - 59/80*n + 2/15))
  print("stdev",np.std(times))
# Out:
# n 3
# number of permutations n! = 6
# exp min = 2
# min formula (n-1) = 2
# exp max = 6
# max formula (n-1)*n = 6
# exp mean = 4.333333333333333
# mean formula 13/18(n**2-n) = 4.333333333333334
# stdev 1.247219128924647
# n 4
# number of permutations n! = 24
# exp min = 3
# min formula (n-1) = 3
# exp max = 12
# max formula (n-1)*n = 12
# exp mean = 8.583333333333334
# mean formula 13/18(n**2-n) = 8.583333333333332
# stdev 2.0395397084200697
# n 5
# number of permutations n! = 120
# exp min = 4
# min formula (n-1) = 4
# exp max = 20
# max formula (n-1)*n = 20
# exp mean = 14.258333333333333
# mean formula 13/18(n**2-n) = 14.258333333333333
# stdev 2.9254510573395156
# n 6
# number of permutations n! = 720
# exp min = 5
# min formula (n-1) = 5
# exp max = 30
# max formula (n-1)*n = 30
# exp mean = 21.377777777777776
# mean formula 13/18(n**2-n) = 21.358333333333334
# stdev 3.8939490888008335
# n 7
# number of permutations n! = 5040
# exp min = 6
# min formula (n-1) = 6
# exp max = 42
# max formula (n-1)*n = 42
# exp mean = 29.954166666666666
# mean formula 13/18(n**2-n) = 29.883333333333333
# stdev 4.9281426300124505
# n 8
# number of permutations n! = 40320
# exp min = 7
# min formula (n-1) = 7
# exp max = 56
# max formula (n-1)*n = 56
# exp mean = 39.995287698412696
# mean formula 13/18(n**2-n) = 39.833333333333336
# stdev 6.019608964038115
# n 9
# number of permutations n! = 362880
# exp min = 8
# min formula (n-1) = 8
# exp max = 72
# max formula (n-1)*n = 72
# exp mean = 51.50684248236332
# mean formula 13/18(n**2-n) = 51.20833333333333
# stdev 7.162493595948604
# n 10
# number of permutations n! = 3628800
# exp min = 9
# min formula (n-1) = 9
# exp max = 90
# max formula (n-1)*n = 90
# exp mean = 64.49318672839506
# mean formula 13/18(n**2-n) = 64.00833333333334
# stdev 8.352008300078836

# %%
from itertools import permutations
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random 

fig = plt.figure()
ax = plt.axes(projection="3d")

N = 10

x = []
y = []
z = []
dx = []
dy = []
dz = []

for n in np.arange(3,N+1,1):
   A = range(n)
   times = []

   for P in permutations(A):
       t = bubbleSort(list(P)) 
       times.append(t)  
 
   b = np.array(range(min(times)-1, max(times)+1))+0.5
   H = np.array(np.histogram(times,b))
   H[0] = H[0]/np.sum(H[0])
   for i in range(len(H[0])):
     x.append(n)
     y.append(H[1][i])
     z.append(0)
     dx.append(0.1)
     dy.append(0.1)
     dz.append(H[0][i])

ax.bar3d(x, y, z, dx, dy, dz, color='aqua', zsort='average')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
# https://towardsdatascience.com/an-easy-introduction-to-3d-plotting-with-matplotlib-801561999725
from itertools import permutations
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random 

fig = plt.figure()
ax = plt.axes(projection="3d")

N = 10

x = []
y = []
z = []
dx = []
dy = []
dz = []

for n in np.arange(3,N+1,1):
   A = range(n)
   times = []

   for P in permutations(A):
       t = bubbleSort(list(P)) 
       times.append(t)  
 
   b = np.array(range(min(times)-1, max(times)+1))+0.5
   H = np.array(np.histogram(times,b))
   H[0] = H[0]/np.sum(H[0])
   for i in range(len(H[0])):
     x.append(n)
     y.append(H[1][i])
     z.append(0)
     dx.append(0.1)
     dy.append(0.1)
     dz.append(H[0][i])

ax.view_init(30, 15)
ax.bar3d(x, y, z, dx, dy, dz, color='aqua', zsort='average')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
import matplotlib.pyplot as plt
import numpy as np

n = np.arange(1,21,1)

plt.plot(n, (n-1),  label = 'Insertion sort best time $(n-1)$', color='aqua')
plt.plot(n, (57/80*n**2-59/80*n+1/3), label = 'Insertion average time $(57/80*n**2 -59/80*n + 1/3)$', color='royalblue')
plt.plot(n, (n-1)*n, label = 'Insertion worst time $(n-1)*n$',color='blue')
plt.xlabel('Array size')
plt.ylabel('Steps')
plt.legend(loc = 'upper left')

# %%
import numpy as np 
import pandas as pd
import scipy.linalg as la

n = np.array([3.0,4.0,5.0,6.0])    # Number n of sorted elments 
t = np.array([39/9,103/12, 1711/120,962/45]) # Average comparisons + swaps for the corresponding n 

data = pd.DataFrame({'n': n, 't': t})
data
# Out:
#      n          t
# 0  3.0   4.333333
# 1  4.0   8.583333
# 2  5.0  14.258333
# 3  6.0  21.377778

# %%
# Interpolating a polynomial of degree 3

X = np.column_stack([n**0,n**1,n**2,n**3])
a = la.solve(X,t)
a
# Out:
# array([-0.06111111, -0.58518519,  0.67361111,  0.00324074])

# %% [markdown]
# ####**Histogramas para permutaciones de $ n $ elementos diferentes con repeticiones:**####

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 
import math

for j in range(3,9):

  n = j
  perm = product(range(1,n+1), repeat = n)

  times =  [] 
# Print the obtained permutations
  for i in list(perm):
    i = list(i)
    times.append(bubbleSort(i))

  b = np.array(range(min(times)-1,max(times)+2) ) +0.5
  plt.hist(times,bins=b)
  plt.title("Bubble Sort")
  plt.xlabel("Steps =comparisons + swaps ")
  plt.ylabel("Frequency")
  plt.show()
    
  print("n",n)  
  print("number of permutations n! =",math.factorial(n)) 
  print("exp min =",min(times))
  print("min formula (n-1) =",(n-1))
  print("exp max =",max(times))
  print("max formula (n-1)*n =",(n-1)*n)
  print("exp mean =",np.mean(times))
  print("mean formula 13/18(n**2-n) =",(57/80*n**2 - 59/80*n + 2/15))
  print("stdev",np.std(times))
# Out:
# n 3
# number of permutations n! = 6
# exp min = 2
# min formula (n-1) = 2
# exp max = 6
# max formula (n-1)*n = 6
# exp mean = 3.6296296296296298
# mean formula 13/18(n**2-n) = 4.333333333333334
# stdev 1.3374422285383547
# n 4
# number of permutations n! = 24
# exp min = 3
# min formula (n-1) = 3
# exp max = 12
# max formula (n-1)*n = 12
# exp mean = 7.46875
# mean formula 13/18(n**2-n) = 8.583333333333332
# stdev 2.2995838618106537
# n 5
# number of permutations n! = 120
# exp min = 4
# min formula (n-1) = 4
# exp max = 20
# max formula (n-1)*n = 20
# exp mean = 12.77152
# mean formula 13/18(n**2-n) = 14.258333333333333
# stdev 3.2691951440071607
# n 6
# number of permutations n! = 720
# exp min = 5
# min formula (n-1) = 5
# exp max = 30
# max formula (n-1)*n = 30
# exp mean = 19.52895661865569
# mean formula 13/18(n**2-n) = 21.358333333333334
# stdev 4.290252772629642
# n 7
# number of permutations n! = 5040
# exp min = 6
# min formula (n-1) = 6
# exp max = 42
# max formula (n-1)*n = 42
# exp mean = 27.74813215581943
# mean formula 13/18(n**2-n) = 29.883333333333333
# stdev 5.373187736730251
# n 8
# number of permutations n! = 40320
# exp min = 7
# min formula (n-1) = 7
# exp max = 56
# max formula (n-1)*n = 56
# exp mean = 37.4370551109314
# mean formula 13/18(n**2-n) = 39.833333333333336
# stdev 6.511226704934139

# %%
from itertools import product
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random 

fig = plt.figure()
ax = plt.axes(projection="3d")

N = 8

x = []
y = []
z = []
dx = []
dy = []
dz = []

for n in np.arange(3,N+1,1):
   A = range(n)
   times = []

   for P in  product(A, repeat = n):
       t = bubbleSort(list(P)) 
       times.append(t)  
 
   b = np.array(range(min(times)-1, max(times)+1))+0.5
   H = np.array(np.histogram(times,b))
   H[0] = H[0]/np.sum(H[0])
   for i in range(len(H[0])):
     x.append(n)
     y.append(H[1][i])
     z.append(0)
     dx.append(0.1)
     dy.append(0.1)
     dz.append(H[0][i])

ax.bar3d(x, y, z, dx, dy, dz, color='aqua', zsort='average')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
from itertools import product
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random 

fig = plt.figure()
ax = plt.axes(projection="3d")

N = 8

x = []
y = []
z = []
dx = []
dy = []
dz = []

for n in np.arange(3,N+1,1):
   A = range(n)
   times = []

   for P in  product(A, repeat = n):
       t = bubbleSort(list(P)) 
       times.append(t)  
 
   b = np.array(range(min(times)-1, max(times)+1))+0.5
   H = np.array(np.histogram(times,b))
   H[0] = H[0]/np.sum(H[0])
   for i in range(len(H[0])):
     x.append(n)
     y.append(H[1][i])
     z.append(0)
     dx.append(0.1)
     dy.append(0.1)
     dz.append(H[0][i])

ax.view_init(30, 15)
ax.bar3d(x, y, z, dx, dy, dz, color='aqua', zsort='average')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
import matplotlib.pyplot as plt
import numpy as np

n = np.arange(1,21,1)

plt.plot(n, (n-1)*n/2,  label = 'Insertion sort best time $(n-1)*n/2$', color='aqua')
plt.plot(n, (3/4)*(n**2)-n+(1/4), label = 'Insertion average time $(3/4)*(n**2)-n+(1/4)$', color='royalblue')
plt.plot(n, (n-1)*n, label = 'Insertion average time $(n-1)*n$',color='blue')
plt.xlabel('Array size')
plt.ylabel('Steps')
plt.legend(loc = 'upper left')

# %%
# Average case on random unifrom permutation of $n$ elements with repetitions $t_a(n) = \frac{3}{4}n^2 - n +\frac{1}{4}= \Theta(n^2) $
import numpy as np 
import pandas as pd
import scipy.linalg as la

n = np.array([3.0,4.0,5.0,6.0])    # Number n of sorted elments 
t = np.array([3626/999 ,7.46875,12.77152,19.5289566]) # Average comparisons + swaps for the corresponding n 

data = pd.DataFrame({'n': n, 't': t})
data
# Out:
#      n          t
# 0  3.0   3.629630
# 1  4.0   7.468750
# 2  5.0  12.771520
# 3  6.0  19.528957

# %%
# Interpolating a polynomial of degree 3

X = np.column_stack([n**0,n**1,n**2,n**3])
a = la.solve(X,t)
a
# Out:
# array([ 0.98399659, -1.3540204 ,  0.74979087, -0.00149717])
